# %% [markdown]
# # Temperature Forecast Project

# %% [markdown]
# This data is for the purpose of bias correction of next-day maximum and minimum air temperatures forecast of the LDAPS model operated by the Korea Meteorological Administration over Seoul, South Korea. This data consists of summer data from 2013 to 2017. The input data is largely composed of the LDAPS model's next-day forecast data, in-situ maximum and minimum temperatures of present-day, and geographic auxiliary variables. There are two outputs (i.e. next-day maximum and minimum air temperatures) in this data. Hindcast validation was conducted for the period from 2015 to 2017.
#
# Attribute Information:
# 1. station - used weather station number: 1 to 25
# 2. Date - Present day: yyyy-mm-dd ('2013-06-30' to '2017-08-30')
# 3. Present_Tmax - Maximum air temperature between 0 and 21 h on the present day (Â°C): 20 to 37.6
# 4. Present_Tmin - Minimum air temperature between 0 and 21 h on the present day (Â°C): 11.3 to 29.9
# 5. LDAPS_RHmin - LDAPS model forecast of next-day minimum relative humidity (%): 19.8 to 98.5
# 6. LDAPS_RHmax - LDAPS model forecast of next-day maximum relative humidity (%): 58.9 to 100
# 7. LDAPS_Tmax_lapse - LDAPS model forecast of next-day maximum air temperature applied lapse rate (Â°C): 17.6 to 38.5
# 8. LDAPS_Tmin_lapse - LDAPS model forecast of next-day minimum air temperature applied lapse rate (Â°C): 14.3 to 29.6
# 9. LDAPS_WS - LDAPS model forecast of next-day average wind speed (m/s): 2.9 to 21.9
# 10. LDAPS_LH - LDAPS model forecast of next-day average latent heat flux (W/m2): -13.6 to 213.4
# 11. LDAPS_CC1 - LDAPS model forecast of next-day 1st 6-hour split average cloud cover (0-5 h) (%): 0 to 0.97
# 12. LDAPS_CC2 - LDAPS model forecast of next-day 2nd 6-hour split average cloud cover (6-11 h) (%): 0 to 0.97
# 13. LDAPS_CC3 - LDAPS model forecast of next-day 3rd 6-hour split average cloud cover (12-17 h) (%): 0 to 0.98
# 14. LDAPS_CC4 - LDAPS model forecast of next-day 4th 6-hour split average cloud cover (18-23 h) (%): 0 to 0.97
# 15. LDAPS_PPT1 - LDAPS model forecast of next-day 1st 6-hour split average precipitation (0-5 h) (%): 0 to 23.7
# 16. LDAPS_PPT2 - LDAPS model forecast of next-day 2nd 6-hour split average precipitation (6-11 h) (%): 0 to 21.6
# 17. LDAPS_PPT3 - LDAPS model forecast of next-day 3rd 6-hour split average precipitation (12-17 h) (%): 0 to 15.8
# 18. LDAPS_PPT4 - LDAPS model forecast of next-day 4th 6-hour split average precipitation (18-23 h) (%): 0 to 16.7
# 19. lat - Latitude (Â°): 37.456 to 37.645
# 20. lon - Longitude (Â°): 126.826 to 127.135
# 21. DEM - Elevation (m): 12.4 to 212.3
# 22. Slope - Slope (Â°): 0.1 to 5.2
# 23. Solar radiation - Daily incoming solar radiation (wh/m2): 4329.5 to 5992.9
# 24. Next_Tmax - The next-day maximum air temperature (Â°C): 17.4 to 38.9
# 25. Next_Tmin - The next-day minimum air temperature (Â°C): 11.3 to 29.8T

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:/Users/jdjra/OneDrive/Desktop/Internship/evaluation projects/2nd phase/temp1.csv')

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['station',
#  'Date',
#  'Present_Tmax',
#  'Present_Tmin',
#  'LDAPS_RHmin',
#  'LDAPS_RHmax',
#  'LDAPS_Tmax_lapse',
#  'LDAPS_Tmin_lapse',
#  'LDAPS_WS',
#  'LDAPS_LH',
#  'LDAPS_CC1',
#  'LDAPS_CC2',
#  'LDAPS_CC3',
#  'LDAPS_CC4',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'lat',
#  'lon',
#  'DEM',
#  'Slope',
#  'Solar radiation',
#  'Next_Tmax',
#  'Next_Tmin']

# %% [markdown]
# Using the Date column for analysis. Not using Year of the date as all the data recorded in one single year therefore only extracting month from it.

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].apply(lambda x:x.month)

# %%
df
# Out:
#       station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0 2013-06-30          28.7          21.4    58.255688
# 1         2.0 2013-06-30          31.9          21.6    52.263397
# 2         3.0 2013-06-30          31.6          23.3    48.690479
# 3         4.0 2013-06-30          32.0          23.4    58.239788
# 4         5.0 2013-06-30          31.4          21.9    56.174095
# ...       ...        ...           ...           ...          ...
# 7747     23.0 2017-08-30          23.3          17.1    26.741310
# 7748     24.0 2017-08-30          23.3          17.7    24.040634
# 7749     25.0 2017-08-30          23.2          17.4    22.933014
# 7750      NaN        NaT          20.0          11.3    19.794666
# 7751      NaN        NaT          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %% [markdown]
# Dropping Date column

# %%
df=df.drop(['Date'],axis=1)

# %%
df
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
# 7750      NaN          20.0          11.3    19.794666    58.936283
# 7751      NaN          37.6          29.9    98.524734   100.000153
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# ...

# %%
df['Month'].unique()
# Out:
# array([ 6.,  1.,  2.,  3.,  4.,  5.,  7.,  8.,  9., 10., 11., 12., nan])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Present_Tmax      7682 non-null   float64
#  2   Present_Tmin      7682 non-null   float64
#  3   LDAPS_RHmin       7677 non-null   float64
#  4   LDAPS_RHmax       7677 non-null   float64
#  5   LDAPS_Tmax_lapse  7677 non-null   float64
#  6   LDAPS_Tmin_lapse  7677 non-null   float64
#  7   LDAPS_WS          7677 non-null   float64
#  8   LDAPS_LH          7677 non-null   float64
#  9   LDAPS_CC1         7677 non-null   float64
#  10  LDAPS_CC2         7677 non-null   float64
#  11  LDAPS_CC3         7677 non-null   float64
#  12  LDAPS_CC4         7677 non-null   float64
#  13  LDAPS_PPT1        7677 non-null   float64
#  14  LDAPS_PPT2        7677 non-null   float64
#  15  LDAPS_PPT3        7677 non-null   float64
# ...

# %% [markdown]
# 1. Removing all the rows where Next_Tmax and Next_Tmin have null values.
# 2. Removing all the rows where LDAPS_RHmin have null values.

# %%
df.dropna(subset=['Next_Tmax'], inplace=True)
df.dropna(subset=['LDAPS_RHmin'],inplace=True)
df.dropna(subset=['Present_Tmax'],inplace=True)

# %%
df
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
# 7750      NaN          20.0          11.3    19.794666    58.936283
# 7751      NaN          37.6          29.9    98.524734   100.000153
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7590 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7588 non-null   float64
#  1   Present_Tmax      7590 non-null   float64
#  2   Present_Tmin      7590 non-null   float64
#  3   LDAPS_RHmin       7590 non-null   float64
#  4   LDAPS_RHmax       7590 non-null   float64
#  5   LDAPS_Tmax_lapse  7590 non-null   float64
#  6   LDAPS_Tmin_lapse  7590 non-null   float64
#  7   LDAPS_WS          7590 non-null   float64
#  8   LDAPS_LH          7590 non-null   float64
#  9   LDAPS_CC1         7590 non-null   float64
#  10  LDAPS_CC2         7590 non-null   float64
#  11  LDAPS_CC3         7590 non-null   float64
#  12  LDAPS_CC4         7590 non-null   float64
#  13  LDAPS_PPT1        7590 non-null   float64
#  14  LDAPS_PPT2        7590 non-null   float64
#  15  LDAPS_PPT3        7590 non-null   float64
# ...

# %% [markdown]
# There are still values missing in multiple columns we will address them later.

# %% [markdown]
# # EDA

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.show()
plt.tight_layout()

# %%
df.isna().sum()
# Out:
# station             2
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Month               2
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer(strategy='most_frequent')

# %%
variables_with_missing = ['station','Month']

# %%
for i in variables_with_missing:
    df[i]=si.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
# 7750      2.0          20.0          11.3    19.794666    58.936283
# 7751      2.0          37.6          29.9    98.524734   100.000153
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# ...

# %%
df.isna().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Month               0
# dtype: int64

# %%
df.skew()
# Out:
# station            -0.003904
# Present_Tmax       -0.258173
# Present_Tmin       -0.363848
# LDAPS_RHmin         0.301392
# LDAPS_RHmax        -0.849594
# LDAPS_Tmax_lapse   -0.226062
# LDAPS_Tmin_lapse   -0.576782
# LDAPS_WS            1.576841
# LDAPS_LH            0.669181
# LDAPS_CC1           0.456982
# LDAPS_CC2           0.474312
# LDAPS_CC3           0.640306
# LDAPS_CC4           0.664487
# LDAPS_PPT1          5.375597
# LDAPS_PPT2          5.772761
# LDAPS_PPT3          6.445912
# LDAPS_PPT4          6.770184
# lat                 0.085498
# lon                -0.288956
# DEM                 1.720915
# Slope               1.558715
# Solar radiation    -0.524522
# Next_Tmax          -0.339116
# Next_Tmin          -0.401286
# Month              -0.703160
# dtype: float64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.113262      0.133392    -0.067827
# Present_Tmax      0.113262      1.000000      0.616291    -0.206529
# Present_Tmin      0.133392      0.616291      1.000000     0.124516
# LDAPS_RHmin      -0.067827     -0.206529      0.124516     1.000000
# LDAPS_RHmax      -0.168588     -0.303867     -0.015260     0.579035
# LDAPS_Tmax_lapse  0.069926      0.574947      0.469881    -0.565579
# LDAPS_Tmin_lapse  0.105358      0.629656      0.772811     0.087319
# LDAPS_WS          0.004830     -0.122206     -0.034831     0.291387
# LDAPS_LH         -0.132316      0.136401     -0.009656    -0.069574
# LDAPS_CC1         0.006357     -0.314411      0.085882     0.613281
# LDAPS_CC2         0.003323     -0.215191      0.091572     0.745043
# LDAPS_CC3        -0.000442     -0.144658     -0.002900     0.688440
# LDAPS_CC4         0.004700     -0.141384     -0.044822     0.514552
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
df.shape
# Out:
# (7590, 25)

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (6748, 25)

# %%
loss=(7590-6748)/7590*100
loss
# Out:
# 11.093544137022397

# %%
df=df_new

# %%
df.skew()
# Out:
# station            -0.001356
# Present_Tmax       -0.268671
# Present_Tmin       -0.220487
# LDAPS_RHmin         0.309883
# LDAPS_RHmax        -0.687985
# LDAPS_Tmax_lapse   -0.111869
# LDAPS_Tmin_lapse   -0.378658
# LDAPS_WS            1.089946
# LDAPS_LH            0.567184
# LDAPS_CC1           0.592894
# LDAPS_CC2           0.504450
# LDAPS_CC3           0.700510
# LDAPS_CC4           0.708209
# LDAPS_PPT1          3.730610
# LDAPS_PPT2          4.839221
# LDAPS_PPT3          5.520425
# LDAPS_PPT4          5.919111
# lat                 0.107095
# lon                -0.277468
# DEM                 1.762716
# Slope               1.588545
# Solar radiation    -0.520398
# Next_Tmax          -0.268945
# Next_Tmin          -0.233267
# Month              -0.681007
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x=df.drop(['Next_Tmax','Next_Tmin'],axis=1)
y1=df['Next_Tmax']
y2=df['Next_Tmin']

# %%
x
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7745     21.0          23.1          17.8    24.688997    78.261383
# 7746     22.0          22.5          17.4    30.094858    83.690018
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0            28.074101         23.006936  6.818887   69.451805   0.233947
# ...

# %%
x1=scaler.fit_transform(x)

# %%
x=pd.DataFrame(x1,columns=x.columns)
x
# Out:
#        station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0    -1.672823     -0.425236     -0.814484     0.194370     0.436477
# 1    -1.534026      0.690620     -0.727771    -0.237751     0.363235
# 2    -1.395229      0.586008      0.009284    -0.495405    -0.586012
# 3    -1.256432      0.725490      0.052640     0.193224     1.204809
# 4    -1.117635      0.516267     -0.597703     0.044260     0.298876
# ...        ...           ...           ...          ...          ...
# 6743  1.103114     -2.377983     -2.375307    -2.226221    -1.403714
# 6744  1.241911     -2.587206     -2.548732    -1.836389    -0.626605
# 6745  1.380708     -2.308242     -2.678800    -2.078223    -1.316611
# 6746  1.519504     -2.308242     -2.418663    -2.272976    -1.542055
# 6747  1.658301     -2.343113     -2.548732    -2.352850    -1.549389
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# ...

# %%
y1
# Out:
# 0       29.1
# 1       30.5
# 2       31.1
# 3       31.7
# 4       31.2
#         ...
# 7745    27.6
# 7746    28.0
# 7747    28.3
# 7748    28.6
# 7749    27.8
# Name: Next_Tmax, Length: 6748, dtype: float64

# %%
y2
# Out:
# 0       21.2
# 1       22.5
# 2       23.9
# 3       24.3
# 4       22.5
#         ...
# 7745    17.7
# 7746    17.1
# 7747    18.1
# 7748    18.8
# 7749    17.4
# Name: Next_Tmin, Length: 6748, dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()

vif['Values'] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features'] = x.columns
print(vif)
# Out:
#       Values          Features
# 0   1.232470           station
# 1   2.701852      Present_Tmax
# 2   3.075663      Present_Tmin
# 3   5.901134       LDAPS_RHmin
# 4   2.232580       LDAPS_RHmax
# 5   6.907996  LDAPS_Tmax_lapse
# 6   6.964547  LDAPS_Tmin_lapse
# 7   1.212029          LDAPS_WS
# 8   1.539860          LDAPS_LH
# 9   3.541110         LDAPS_CC1
# 10  4.724794         LDAPS_CC2
# 11  4.901572         LDAPS_CC3
# 12  2.741502         LDAPS_CC4
# 13  1.549932        LDAPS_PPT1
# 14  1.416295        LDAPS_PPT2
# 15  1.258702        LDAPS_PPT3
# 16  1.272851        LDAPS_PPT4
# 17  1.225384               lat
# 18  1.173258               lon
# 19  3.132699               DEM
# 20  2.951420             Slope
# 21  1.339591   Solar radiation
# 22  1.126972             Month

# %%
#importing libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#importing models
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR

# %% [markdown]
# # Temp_Max model

# %%
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y1_train,y1_test=train_test_split(x,y1,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y1_train)
    pred=lr.predict(x_test)
    acc=r2_score(y1_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRs = i
print(maxAccu, maxRs)
# Out:
# 0.7926313208950776 84

# %%
def model(m):
    m.fit(x_train,y1_train)
    pred=m.predict(x_test)
    print('R2 Score: ',r2_score(y1_test,pred)*100)
    print('R2 Score on training data: ',r2_score(y1_train,m.predict(x_train))*100)
    print('MAE: ',mean_absolute_error(y1_test,pred))
    print('MSE: ',mean_squared_error(y1_test,pred))
    print('RMSE: ',np.sqrt(mean_squared_error(y1_test,pred)))
    sns.regplot(x=pred,y=y1_test)

# %% [markdown]
# LinearRegression

# %%
lr=LinearRegression()
model(lr)
# Out:
# R2 Score:  78.22020812698916
# R2 Score on training data:  75.75240458238865
# MAE:  1.0683115324849792
# MSE:  1.943452200275388
# RMSE:  1.394077544570383

# %% [markdown]
# RandomForestRegressor

# %%
rfr=RandomForestRegressor()
model(rfr)
# Out:
# R2 Score:  89.57776771193605
# R2 Score on training data:  98.47660926868906
# MAE:  0.7172955555555554
# MSE:  0.9299955844444442
# RMSE:  0.9643627867376697

# %% [markdown]
# AdaBoostRegressor

# %%
adr=AdaBoostRegressor()
model(adr)
# Out:
# R2 Score:  75.95657615197628
# R2 Score on training data:  76.26065090333256
# MAE:  1.1779542034625767
# MSE:  2.1454403812508005
# RMSE:  1.4647321875519772

# %% [markdown]
# GradientBoostingRegressor

# %%
gbr=GradientBoostingRegressor()
model(gbr)
# Out:
# R2 Score:  85.28472548440972
# R2 Score on training data:  86.49650783109381
# MAE:  0.8845602188416213
# MSE:  1.3130718971846091
# RMSE:  1.1458934929497633

# %% [markdown]
# DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()
model(dtr)
# Out:
# R2 Score:  76.6072695001679
# R2 Score on training data:  100.0
# MAE:  1.0302222222222222
# MSE:  2.0873777777777778
# RMSE:  1.4447760303167332

# %% [markdown]
# KNN

# %%
model(KNN())
# Out:
# R2 Score:  83.99304209901636
# R2 Score on training data:  89.27759788286622
# MAE:  0.8846222222222222
# MSE:  1.4283312592592594
# RMSE:  1.1951281350797744

# %% [markdown]
# Lasso

# %%
model(Lasso())
# Out:
# R2 Score:  55.37057653396457
# R2 Score on training data:  54.30547416946167
# MAE:  1.602735328929861
# MSE:  3.982368230964107
# RMSE:  1.9955871895169368

# %% [markdown]
# Ridge

# %%
model(Ridge())
# Out:
# R2 Score:  78.22037302144689
# R2 Score on training data:  75.75239690091765
# MAE:  1.068311930390455
# MSE:  1.9434374864297035
# RMSE:  1.3940722672909405

# %% [markdown]
# Support Vector Regressor

# %%
model(SVR())
# Out:
# R2 Score:  86.3933131870813
# R2 Score on training data:  87.4415728968783
# MAE:  0.7961241778363198
# MSE:  1.2141505106756247
# RMSE:  1.1018849806924609

# %%
from sklearn.model_selection import cross_val_score

# %%
def scr(m):
    score=cross_val_score(m,x,y1)
    print(score)
    print(score.mean())
    print('Diff b/w R2 score & CV score: ',(r2_score(y1_test,pred) - score.mean())*100)

# %% [markdown]
# LinearRegression

# %%
scr(lr)
# Out:
# [0.72789739 0.66916563 0.68799424 0.71924709 0.66067806]
# 0.692996482248029
# Diff b/w R2 score & CV score:  8.920559902186264

# %% [markdown]
# RandomForestRegressor

# %%
scr(rfr)
# Out:
# [0.7198234  0.65621674 0.65179166 0.7036396  0.60711425]
# 0.6677171305714271
# Diff b/w R2 score & CV score:  11.448495069846453

# %% [markdown]
# DecisionTreesRegressor

# %%
scr(dtr)
# Out:
# [0.40657727 0.36455683 0.34715013 0.51376598 0.37154036]
# 0.40071811500572335
# Diff b/w R2 score & CV score:  38.14839662641683

# %% [markdown]
# GradientBoostingRegressor

# %%
scr(gbr)
# Out:
# [0.72493025 0.67700684 0.68590179 0.72340386 0.63518914]
# 0.6892863765320063
# Diff b/w R2 score & CV score:  9.291570473788536

# %% [markdown]
# AbaBoostRegressor

# %%
scr(adr)
# Out:
# [0.72441941 0.65561002 0.62291811 0.64772049 0.61121836]
# 0.6523772784045361
# Diff b/w R2 score & CV score:  12.982480286535559

# %% [markdown]
# KNN

# %%
scr(KNN())
# Out:
# [0.59952407 0.4456271  0.49134282 0.5569791  0.57941349]
# 0.5345773184772872
# Diff b/w R2 score & CV score:  24.762476279260447

# %% [markdown]
# Lasso

# %%
scr(Lasso())
# Out:
# [0.49443374 0.47196085 0.56707906 0.42351005 0.52841656]
# 0.49708005206450245
# Diff b/w R2 score & CV score:  28.512202920538922

# %% [markdown]
# Ridge

# %%
scr(Ridge())
# Out:
# [0.72803604 0.66910861 0.68795838 0.71932325 0.66073325]
# 0.6930319057889031
# Diff b/w R2 score & CV score:  8.91701754809886

# %% [markdown]
# Support Vector Regressor

# %%
scr(SVR())
# Out:
# [0.66276672 0.56146982 0.66220475 0.68446495 0.65906602]
# 0.6459944537722525
# Diff b/w R2 score & CV score:  13.620762749763916

# %% [markdown]
# # Random Forest Regressor is our Best Model!

# %% [markdown]
# Hyperparameter tuning

# %%
#importing RandomizedseachCV for hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters = {
    'ccp_alpha': [0.0, 0.01, 0.001],
    'warm_start': [True, False],
    'random_state': [10, 20],
    'oob_score': [True, False],
    'bootstrap': [True, False],
    'criterion': ['squared_error', 'absolute_error'],
    'n_jobs': [1],
    'n_estimators': [10, 20]
}

# %%
rsv = RandomizedSearchCV(RandomForestRegressor(),parameters,n_iter=10, n_jobs=-1)
rsv.fit(x_train, y1_train)
print(rsv.best_params_)
# Out:
# {'warm_start': False, 'random_state': 10, 'oob_score': True, 'n_jobs': 1, 'n_estimators': 20, 'criterion': 'absolute_error', 'ccp_alpha': 0.001, 'bootstrap': True}

# %%
Hyper_rfr=RandomForestRegressor(warm_start=False,random_state=10,oob_score=True,n_jobs=1,n_estimators=20,criterion='absolute_error',ccp_alpha=0.001,bootstrap=True)

# %%
model(Hyper_rfr)
# Out:
# R2 Score:  87.14720663057595
# R2 Score on training data:  93.54497421054684
# MAE:  0.8064666666666667
# MSE:  1.1468791666666664
# RMSE:  1.070924444891733

# %% [markdown]
# R2 score after hypertuning is 87.14%

# %%
Final_model=Hyper_rfr

# %%
#Saving our model
import joblib
joblib.dump(Final_model,'Prediction_Maxtemp.pkl')
# Out:
# ['Prediction_Maxtemp.pkl']

# %%
model=joblib.load('Prediction_Maxtemp.pkl')
Prediction=model.predict(x_test)
Prediction
# Out:
# array([27.585 , 26.8425, 23.8125, ..., 33.0325, 34.2075, 31.8225])

# %%
Comparison=pd.DataFrame()
Comparison['True Value']=y1_test
Comparison['Prediciton']=Prediction
Comparison
# Out:
#       True Value  Prediciton
# 7667        28.4     27.5850
# 6446        26.9     26.8425
# 5033        23.8     23.8125
# 3828        34.9     30.7875
# 6803        36.1     32.8475
# ...          ...         ...
# 1116        33.0     32.4475
# 5521        35.9     35.6700
# 3860        33.0     33.0325
# 7012        33.5     34.2075
# 2058        31.7     31.8225
#
# [1350 rows x 2 columns]

# %% [markdown]
# # Temp_Min model

# %%
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y2_train,y2_test=train_test_split(x,y2,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y2_train)
    pred=lr.predict(x_test)
    acc=r2_score(y2_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRs = i
print(maxAccu, maxRs)
# Out:
# 0.8408733276329484 98

# %%
def model(m):
    m.fit(x_train,y2_train)
    pred=m.predict(x_test)
    print('R2 Score: ',r2_score(y2_test,pred)*100)
    print('R2 Score on training data: ',r2_score(y2_train,m.predict(x_train))*100)
    print('MAE: ',mean_absolute_error(y2_test,pred))
    print('MSE: ',mean_squared_error(y2_test,pred))
    print('RMSE: ',np.sqrt(mean_squared_error(y2_test,pred)))
    sns.regplot(x=pred,y=y2_test)

# %% [markdown]
# LinearRegression

# %%
lr=LinearRegression()
model(lr)
# Out:
# R2 Score:  79.78588369882692
# R2 Score on training data:  82.89831416954266
# MAE:  0.8388078309649337
# MSE:  1.099966060927275
# RMSE:  1.0487926682272692

# %% [markdown]
# RandomForestRegressor

# %%
rfr=RandomForestRegressor()
model(rfr)
# Out:
# R2 Score:  88.62237765123524
# R2 Score on training data:  98.57190399095163
# MAE:  0.611434814814815
# MSE:  0.6191217192592594
# RMSE:  0.7868428809230337

# %% [markdown]
# AdaBoostRegressor

# %%
adr=AdaBoostRegressor()
model(adr)
# Out:
# R2 Score:  77.87273851412311
# R2 Score on training data:  81.41246825985286
# MAE:  0.8994698904249246
# MSE:  1.2040712684687251
# RMSE:  1.097301812843087

# %% [markdown]
# GradientBoostingRegressor

# %%
gbr=GradientBoostingRegressor()
model(gbr)
# Out:
# R2 Score:  86.68186151623185
# R2 Score on training data:  90.39269296771468
# MAE:  0.672090642107123
# MSE:  0.724716337266955
# RMSE:  0.8513027295075207

# %% [markdown]
# DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()
model(dtr)
# Out:
# R2 Score:  75.34033134440895
# R2 Score on training data:  100.0
# MAE:  0.8597777777777779
# MSE:  1.3418740740740742
# RMSE:  1.1583928841606694

# %% [markdown]
# KNN

# %%
model(KNN())
# Out:
# R2 Score:  84.53424012390009
# R2 Score on training data:  90.94015762619088
# MAE:  0.7129037037037037
# MSE:  0.8415807407407407
# RMSE:  0.9173770984392082

# %% [markdown]
# Lasso

# %%
model(Lasso())
# Out:
# R2 Score:  58.34141268476313
# R2 Score on training data:  60.453780082712605
# MAE:  1.1943815554486317
# MSE:  2.266882781824938
# RMSE:  1.505617076757878

# %% [markdown]
# Ridge

# %%
model(Ridge())
# Out:
# R2 Score:  79.78686563881611
# R2 Score on training data:  82.89830814155246
# MAE:  0.838794285173109
# MSE:  1.0999126279378788
# RMSE:  1.0487671943467143

# %% [markdown]
# Supportt Vector Regressor

# %%
model(SVR())
# Out:
# R2 Score:  88.20532359781717
# R2 Score on training data:  92.04319161023388
# MAE:  0.6073695197853354
# MSE:  0.6418160234522862
# RMSE:  0.8011342106365738

# %%
from sklearn.model_selection import cross_val_score

# %%
def scr(m):
    score=cross_val_score(m,x,y2)
    print(score)
    print(score.mean())
    print('Diff b/w R2 score & CV score: ',(r2_score(y2_test,pred) - score.mean())*100)

# %%
scr(lr)
# Out:
# [0.71656644 0.65850744 0.78512494 0.85768253 0.8454362 ]
# 0.7726635079681885
# Diff b/w R2 score & CV score:  2.5195329020080703

# %%
scr(rfr)
# Out:
# [0.70449213 0.69754014 0.79884466 0.85603375 0.8500563 ]
# 0.7813933927588652
# Diff b/w R2 score & CV score:  1.6465444229403992

# %%
scr(dtr)
# Out:
# [0.44448688 0.49187416 0.63630118 0.72564018 0.68129653]
# 0.5959197856186944
# Diff b/w R2 score & CV score:  20.19390513695748

# %%
scr(gbr)
# Out:
# [0.73757979 0.67855337 0.80387366 0.86864888 0.8689163 ]
# 0.7915143995249329
# Diff b/w R2 score & CV score:  0.634443746333635

# %%
scr(adr)
# Out:
# [0.69177916 0.59681043 0.74827399 0.81328257 0.82610829]
# 0.735250888805511
# Diff b/w R2 score & CV score:  6.260794818275817

# %%
scr(KNN())
# Out:
# [0.59791131 0.50431662 0.62967943 0.6996603  0.74332555]
# 0.6349786406871467
# Diff b/w R2 score & CV score:  16.28801963011225

# %%
scr(Lasso())
# Out:
# [0.54732288 0.40908141 0.57976578 0.500656   0.63037573]
# 0.5334403596097426
# Diff b/w R2 score & CV score:  26.441847737852665

# %%
scr(Ridge())
# Out:
# [0.71659144 0.65855403 0.78510775 0.85769414 0.84545004]
# 0.7726794781338505
# Diff b/w R2 score & CV score:  2.5179358854418687

# %%
scr(SVR())
# Out:
# [0.66644611 0.64157165 0.77604675 0.79017913 0.81118274]
# 0.7370852776256329
# Diff b/w R2 score & CV score:  6.077355936263629

# %% [markdown]
# # RandomForestRegressor is our best model!

# %% [markdown]
# Hyperparameter tuning

# %%
#importing RandomizedseachCV for hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters = {
    'ccp_alpha': [0.0, 0.01, 0.001],
    'warm_start': [True, False],
    'random_state': [10, 20],
    'oob_score': [True, False],
    'bootstrap': [True, False],
    'criterion': ['squared_error', 'absolute_error'],
    'n_jobs': [1],
    'n_estimators': [10, 20]
}

# %%
rsv = RandomizedSearchCV(RandomForestRegressor(),parameters,n_iter=10, n_jobs=-1)
rsv.fit(x_train, y1_train)
print(rsv.best_params_)
# Out:
# {'warm_start': False, 'random_state': 20, 'oob_score': True, 'n_jobs': 1, 'n_estimators': 20, 'criterion': 'absolute_error', 'ccp_alpha': 0.0, 'bootstrap': True}

# %%
Hyper_rfr=RandomForestRegressor(warm_start=False,random_state=20,oob_score=True,n_jobs=1,n_estimators=20,criterion='absolute_error',ccp_alpha=0.0,bootstrap=True)

# %%
model(Hyper_rfr)
# Out:
# R2 Score:  87.83754737780217
# R2 Score on training data:  98.19519292352896
# MAE:  0.6303796296296298
# MSE:  0.661828837962963
# RMSE:  0.8135286337695576

# %% [markdown]
# After Hypertuning R2score is 87.37%

# %%
Final_model=Hyper_rfr

# %%
#Saving our model
import joblib
joblib.dump(Final_model,'Prediction_Mintemp.pkl')
# Out:
# ['Prediction_Mintemp.pkl']

# %%
model=joblib.load('Prediction_Mintemp.pkl')
Prediction=model.predict(x_test)
Prediction
# Out:
# array([19.125, 23.33 , 20.05 , ..., 26.075, 25.24 , 23.55 ])

# %%
Comparison=pd.DataFrame()
Comparison['True Value']=y2_test
Comparison['Prediciton']=Prediction
Comparison
# Out:
#       True Value  Prediciton
# 7667        18.3      19.125
# 6446        23.1      23.330
# 5033        19.8      20.050
# 3828        25.8      24.885
# 6803        24.2      24.185
# ...          ...         ...
# 1116        22.7      24.120
# 5521        26.6      26.140
# 3860        26.7      26.075
# 7012        26.7      25.240
# 2058        23.0      23.550
#
# [1350 rows x 2 columns]

# %% [markdown]
# # Minimum Temp prediction model = Prediction_Mintemp.pkl
# # Maximum Temp prediction midel = Prediction_Maxtemp.pkl
